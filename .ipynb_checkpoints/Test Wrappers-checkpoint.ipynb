# %%
from lib.project_5 import load_data_from_database
import pandas as pd

# %%
data = load_data_from_database(database = 'dsi')
# Out:
#       index  feat_000  feat_001  feat_002  feat_003  feat_004  feat_005  \
# 0         0       485       477       537       479       452       471
# 1         1       483       458       460       487       587       475
# 2         2       487       542       499       468       448       471
# 3         3       480       491       510       485       495       472
# 4         4       484       502       528       489       466       481
# 5         5       481       496       451       480       516       484
# 6         6       484       533       498       466       577       482
# 7         7       474       468       598       490       530       482
# 8         8       484       498       558       489       508       478
# 9         9       496       448       570       476       477       481
# 10       10       478       446       457       475       468       475
# 11       11       486       479       528       483       530       484
# ...
